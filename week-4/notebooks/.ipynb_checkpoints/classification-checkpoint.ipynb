# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %config InlineBackend.figure_format = 'retina'

# %%
RANDOM_SEED = 666

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## Airline Passenger Satisfaction

# %%
data = pd.read_csv("../data/airline_satisfaction/train.csv", index_col=0)
data.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  Gate location  Food and drink  Online boarding  \
# 0                       3              1               5                3
# 1                       3              3               1                3
# 2                       2              2               5                5
# 3                       5              5               2                2
# 4                       3              3               4                5
#
#    Seat comfort  Inflight entertainment  On-board service  Leg room service  \
# 0             5                       5                 4                 3
# 1             1                       1                 1                 5
# 2             5                       5                 4                 3
# 3             2                       2                 2                 5
# 4             5                       3                 3                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                4                 5            5
# 1                 3                1                 4            1
# 2                 4                4                 4            5
# 3                 3                1                 4            2
# 4                 4                3                 3            3
#
#    Departure Delay in Minutes  Arrival Delay in Minutes  \
# 0                          25                      18.0
# 1                           1                       6.0
# 2                           0                       0.0
# 3                          11                       9.0
# 4                           0                       0.0
#
#               satisfaction
# 0  neutral or dissatisfied
# 1  neutral or dissatisfied
# 2                satisfied
# 3  neutral or dissatisfied
# 4                satisfied

# %%
# Train a simple model using only numerical features
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder

# %%
ignore_features = ["id"]
features = [
    column
    for column, series in data.items()
    if np.issubdtype(series.dtype, np.number)
    and column not in ignore_features
]
target = "satisfaction"

# %%
X = data[features]
# y is 0s and 1s
y = LabelEncoder().fit_transform(data[target])

# %%
X.shape
# Out:
# (103904, 18)

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
imputer = SimpleImputer()
X_trans = imputer.fit_transform(X)

# %%
model = LogisticRegression(random_state=RANDOM_SEED)
model = model.fit(X_trans, y)
# Out:
# /home/akshayghime/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
imputer = SimpleImputer()

X_trans = imputer.fit_transform(scaler.fit_transform(X))

# %%
model = LogisticRegression(random_state=RANDOM_SEED)
model = model.fit(X_trans, y)

# %%
# predict_proba to get probabilities
y_pred_proba = model.predict_proba(X_trans)

# %%
# The output of predict_proba is N x C
# N -> number of samples
# C -> number of classes
print(y_pred_proba.shape)
# Out:
# (103904, 2)

# %%
y_pred_proba
# Out:
# array([[0.6745082 , 0.3254918 ],
#        [0.92107446, 0.07892554],
#        [0.14715698, 0.85284302],
#        ...,
#        [0.78770765, 0.21229235],
#        [0.87276054, 0.12723946],
#        [0.99150026, 0.00849974]])

# %%
# predict gives classes.
# It assumes a default threshold of 0.5

# %%
y_pred = model.predict(X_trans)

# %%
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
from sklearn.metrics import ConfusionMatrixDisplay

# %%
ax = ConfusionMatrixDisplay.from_predictions(y, y_pred)

# %%
from sklearn.metrics import classification_report

# %%
# Quick view of metrics:
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85     58879
#            1       0.82      0.78      0.80     45025
#
#     accuracy                           0.83    103904
#    macro avg       0.83      0.82      0.82    103904
# weighted avg       0.83      0.83      0.83    103904

# %%
# Individual metrics available too
from sklearn.metrics import f1_score, precision_score, recall_score

# %%
for func in (precision_score, recall_score, f1_score):
    print(f"{func.__name__+':':20s} {func(y, y_pred):.4f}")
# Out:
# precision_score:     0.8161
# recall_score:        0.7792
# f1_score:            0.7972

# %% [markdown]
# #### The threshold is a choice!

# %%
threshold = 0.4

# %%
print(classification_report(y, y_pred_proba[:, 1] >= threshold))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.80      0.83     58879
#            1       0.76      0.83      0.79     45025
#
#     accuracy                           0.81    103904
#    macro avg       0.81      0.81      0.81    103904
# weighted avg       0.82      0.81      0.81    103904

# %%
from sklearn.metrics import PrecisionRecallDisplay, RocCurveDisplay

# %%
ax = PrecisionRecallDisplay.from_predictions(y, y_pred_proba[:, 1])

# %%
ax = RocCurveDisplay.from_predictions(y, y_pred_proba[:, 1])

# %% [markdown]
# ## Global Speech Accent Recognition

# %%
data = pd.read_csv("../data/accent_recognition/train.csv")
data.head()
# Out:
#           X1        X2        X3         X4        X5         X6         X7  \
# 0   8.118459 -2.784780  0.414908   0.907955 -7.995316  15.525385 -10.439900
# 1  -2.374189 -7.297245  7.349022   7.524122 -7.129271  11.292515 -13.649587
# 2  -0.791621  1.303788 -1.791229   6.227355 -9.602931   8.602848  -7.727415
# 3  -3.177167 -4.239308  1.106003  10.937736 -8.870120   6.314209  -9.932148
# 4  10.978152  1.643641  6.195087   1.265713  5.735026   9.046351  -7.799853
#
#          X8        X9       X10       X11       X12 language
# 0  5.001569 -1.512281 -2.719342  2.222301 -5.846886       US
# 1  4.615975 -0.784158 -4.178449  1.320741  2.530421       ES
# 2  6.436677 -0.055187  0.486530  1.698110 -1.761528       FR
# 3  0.379124 -1.273991 -0.336232  5.219751 -5.748222       US
# 4  0.789758 -2.697877 -9.736504  4.329233 -4.248319       UK

# %%
features = [
    "X1",
    "X2",
    "X3",
    "X4",
    "X5",
    "X6",
    "X7",
    "X8",
    "X9",
    "X10",
    "X11",
    "X12",
]
target = "language"

# %%
X = data[features]
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(data[target])

# %%
y
# Out:
# array([5, 0, 1, ..., 5, 4, 0])

# %%
scaler = StandardScaler()
X_trans = scaler.fit_transform(X)

# %%
model = LogisticRegression(random_state=RANDOM_SEED)
model.fit(X_trans, y)
# Out:
# LogisticRegression(random_state=666)

# %%
y_pred_proba = model.predict_proba(X_trans)

# %%
y_pred_proba.shape
# Out:
# (3960, 6)

# %%
y_pred_proba
# Out:
# array([[0.08991624, 0.0863662 , 0.10890095, 0.10578192, 0.1581603 ,
#         0.45087439],
#        [0.10614236, 0.07575609, 0.09668161, 0.08954678, 0.13284202,
#         0.49903115],
#        [0.05705313, 0.08416551, 0.12282936, 0.10531556, 0.15623697,
#         0.47439947],
#        ...,
#        [0.06100477, 0.07138678, 0.12132416, 0.06640055, 0.18442051,
#         0.49546324],
#        [0.10793926, 0.07892478, 0.10522332, 0.07111329, 0.1463854 ,
#         0.49041394],
#        [0.13519114, 0.07263368, 0.10201795, 0.0734189 , 0.16600853,
#         0.4507298 ]])

# %%
y_pred = model.predict(X_trans)

# %%
y_pred
# Out:
# array([5, 5, 5, ..., 5, 5, 5])

# %%
ConfusionMatrixDisplay.from_predictions(y, y_pred)

# %%
label_encoder.inverse_transform([5])
# Out:
# array(['US'], dtype=object)

# %%
data[target].value_counts()
# Out:
# US    1933
# UK     647
# GE     414
# ES     339
# IT     327
# FR     300
# Name: language, dtype: int64

# %%
model = LogisticRegression(class_weight="balanced", random_state=RANDOM_SEED)
model.fit(X_trans, y)
# Out:
# LogisticRegression(class_weight='balanced', random_state=666)

# %%
y_pred = model.predict(X_trans)

# %%
ax = ConfusionMatrixDisplay.from_predictions(y, y_pred)

# %%
print(classification_report(y, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.11      0.31      0.17       339
#            1       0.09      0.15      0.11       300
#            2       0.14      0.26      0.18       414
#            3       0.10      0.19      0.13       327
#            4       0.20      0.20      0.20       647
#            5       0.56      0.14      0.22      1933
#
#     accuracy                           0.18      3960
#    macro avg       0.20      0.21      0.17      3960
# weighted avg       0.34      0.18      0.19      3960

# %%
for func in (precision_score, recall_score, f1_score):
    for avg in ("micro", "macro"):
        print(f"{func.__name__+f' ({avg}):':30s} {func(y, y_pred, average=avg):.4f}")

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(class_weight="balanced", random_state=RANDOM_SEED)
model.fit(X_trans, y)

# %%
y_pred = model.predict(X_trans)

# %%
ax = ConfusionMatrixDisplay.from_predictions(y, y_pred)
